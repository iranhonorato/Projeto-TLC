# %%
import pandas as pd

# %%
df = pd.read_excel("../pdfs_CO.xlsx")
df
# Out:
#                             Nome    Núcleo  \
# 0    Adriana Bruscato Bortoluzzo     Dados
# 1    Adriana Bruscato Bortoluzzo     Dados
# 2    Adriana Bruscato Bortoluzzo     Dados
# 3    Adriana Bruscato Bortoluzzo     Dados
# 4    Adriana Bruscato Bortoluzzo     Dados
# ..                           ...       ...
# 517             Sérgio Lazzarini  Metricis
# 518             Sérgio Lazzarini  Metricis
# 519             Sérgio Lazzarini  Metricis
# 520             Sérgio Lazzarini  Metricis
# 521              Vanessa Boarati     Saúde
#
#                                               Trabalho  Data Publicação  \
# 0    https://repositorio.insper.edu.br/entities/pub...             2020
# 1    https://repositorio.insper.edu.br/entities/pub...             2016
# 2    https://repositorio.insper.edu.br/entities/pub...             2009
# 3    https://repositorio.insper.edu.br/entities/pub...             2022
# 4    https://repositorio.insper.edu.br/entities/pub...             2011
# ...

# %%
df = df[df["Categoria"] != "Livro"].reset_index(drop=True)
df
# Out:
#                             Nome    Núcleo  \
# 0    Adriana Bruscato Bortoluzzo     Dados
# 1    Adriana Bruscato Bortoluzzo     Dados
# 2    Adriana Bruscato Bortoluzzo     Dados
# 3    Adriana Bruscato Bortoluzzo     Dados
# 4    Adriana Bruscato Bortoluzzo     Dados
# ..                           ...       ...
# 497             Sérgio Lazzarini  Metricis
# 498             Sérgio Lazzarini  Metricis
# 499             Sérgio Lazzarini  Metricis
# 500             Sérgio Lazzarini  Metricis
# 501              Vanessa Boarati     Saúde
#
#                                               Trabalho  Data Publicação  \
# 0    https://repositorio.insper.edu.br/entities/pub...             2020
# 1    https://repositorio.insper.edu.br/entities/pub...             2016
# 2    https://repositorio.insper.edu.br/entities/pub...             2009
# 3    https://repositorio.insper.edu.br/entities/pub...             2022
# 4    https://repositorio.insper.edu.br/entities/pub...             2011
# ...

# %%
df = df.dropna(subset=["ods"])
df = df.reset_index(drop=True)
df
# Out:
#                             Nome    Núcleo  \
# 0    Adriana Bruscato Bortoluzzo     Dados
# 1    Adriana Bruscato Bortoluzzo     Dados
# 2    Adriana Bruscato Bortoluzzo     Dados
# 3    Adriana Bruscato Bortoluzzo     Dados
# 4    Adriana Bruscato Bortoluzzo     Dados
# ..                           ...       ...
# 457             Sérgio Lazzarini  Metricis
# 458             Sérgio Lazzarini  Metricis
# 459             Sérgio Lazzarini  Metricis
# 460             Sérgio Lazzarini  Metricis
# 461              Vanessa Boarati     Saúde
#
#                                               Trabalho  Data Publicação  \
# 0    https://repositorio.insper.edu.br/entities/pub...             2020
# 1    https://repositorio.insper.edu.br/entities/pub...             2016
# 2    https://repositorio.insper.edu.br/entities/pub...             2009
# 3    https://repositorio.insper.edu.br/entities/pub...             2022
# 4    https://repositorio.insper.edu.br/entities/pub...             2011
# ...

# %%
df.to_excel("../db.xlsx")
